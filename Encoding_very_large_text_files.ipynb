# %% [markdown]
# # Optional: downloading training texts

# %%
# !pip install dtrx
# Out:
# Collecting dtrx
#   Downloading dtrx-8.2.0-py2.py3-none-any.whl (28 kB)
# Collecting subprocess32
#   Downloading subprocess32-3.5.4.tar.gz (97 kB)
#      |████████████████████████████████| 97 kB 6.1 MB/s
# Building wheels for collected packages: subprocess32
#   Building wheel for subprocess32 (setup.py) ... done
#   Created wheel for subprocess32: filename=subprocess32-3.5.4-py3-none-any.whl size=6502 sha256=50b2f3c9fc19fb0c1dcdc7dc213fc4b9993e05c1ba477702f5621d8433d8bdc2
#   Stored in directory: /root/.cache/pip/wheels/50/ca/fa/8fca8d246e64f19488d07567547ddec8eb084e8c0d7a59226a
# Successfully built subprocess32
# Installing collected packages: subprocess32, dtrx
# Successfully installed dtrx-8.2.0 subprocess32-3.5.4

# %%
# !lang="vi"; wget -c https://dumps.wikimedia.org/${lang}wiki/latest/${lang}wiki-latest-pages-articles.xml.bz2 & wget https://object.pouta.csc.fi/OPUS-WikiMatrix/v1/mono/${lang}.txt.gz & wget https://object.pouta.csc.fi/OPUS-wikimedia/v20210402/mono/${lang}.txt.gz & wget https://object.pouta.csc.fi/OPUS-CCAligned/v1/mono/${lang}.txt.gz & wget https://object.pouta.csc.fi/OPUS-OpenSubtitles/v2018/mono/${lang}.txt.gz & wget https://object.pouta.csc.fi/OPUS-XLEnt/v1.1/mono/${lang}.txt.gz & wget https://object.pouta.csc.fi/OPUS-JW300/v1b/mono/${lang}.txt.gz & wget https://object.pouta.csc.fi/OPUS-TED2020/v1/mono/${lang}.txt.gz & wget https://object.pouta.csc.fi/OPUS-QED/v2.0a/mono/${lang}.txt.gz & wget https://object.pouta.csc.fi/OPUS-GNOME/v1/mono/${lang}.txt.gz & wget https://object.pouta.csc.fi/OPUS-bible-uedin/v1/mono/${lang}.txt.gz & wget https://object.pouta.csc.fi/OPUS-ParaCrawl/v8/mono/${lang}.txt.gz & wget https://object.pouta.csc.fi/OPUS-TildeMODEL/v2018/mono/${lang}.txt.gz & wget https://object.pouta.csc.fi/OPUS-DGT/v2019/mono/${lang}.txt.gz & wget https://object.pouta.csc.fi/OPUS-EUbookshop/v2/mono/${lang}.txt.gz & wget https://object.pouta.csc.fi/OPUS-SETIMES/v2/mono/${lang}.txt.gz

# %%
# !dtrx *.txt.gz.* & dtrx *.txt.gz & dtrx *.bz2

# %%
# !cat *.txt > dataset.txt

# %% [markdown]
# # Downloading and cleaning Wikipedia

# %%
# !nohup curl -L -O https://dumps.wikimedia.org/ltwiki/latest/ltwiki-latest-pages-articles.xml.bz2 &

# %%
# !pip install wikiextractor
# Out:
# Collecting wikiextractor
#   Downloading wikiextractor-3.0.4-py3-none-any.whl (46 kB)
#      |████████████████████████████████| 46 kB 1.9 MB/s
# Installing collected packages: wikiextractor
# Successfully installed wikiextractor-3.0.4

# %%
# !python3 -m wikiextractor.WikiExtractor -o wiki-lt/ --no-templates --processes 8 ltwiki-latest-pages-articles.xml.bz2
# Out:
# INFO: Starting page extraction from ltwiki-latest-pages-articles.xml.bz2.
# INFO: Using 8 extract processes.
# INFO: Extracted 100000 articles (430.4 art/s)
# INFO: Extracted 200000 articles (558.9 art/s)
# INFO: Finished 8-process extraction of 286412 articles in 615.0s (465.7 art/s)

# %%
# !du; ls -s

# %%
# !cat wiki*/*/* > final_untokenised.txt

# %%
# !cat wiki*/AA/wiki_*0* > tokentrain_final.txt

# %% [markdown]
# # Training the tokeniser

# %%
# !pip install youtokentome & pip install tokenizers
# Out:
# Collecting youtokentome
#   Downloading youtokentome-1.0.6-cp37-cp37m-manylinux2010_x86_64.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 5.1 MB/s
# Requirement already satisfied: Click>=7.0 in /usr/local/lib/python3.7/dist-packages (from youtokentome) (7.1.2)
# Collecting tokenizers
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 4.7 MB/s
# Installing collected packages: youtokentome
# Installing collected packages: tokenizers
# Successfully installed youtokentome-1.0.6
# Successfully installed tokenizers-0.10.3

# %%
import youtokentome as yttm

# %%
yttm.BPE.train('/content/tokentrain_final.txt', 'model', 50000, 0.9999, n_threads=-1, pad_id=0, unk_id=1, bos_id=2, eos_id=3)

# %%
# !yttm vocab --model model > vocab.txt

# %%
# !sed 's/^ *[0-9]\+.//g' /content/vocab.txt > /content/cleanvocab.txt

# %%
text_file = open("/content/cleanvocab.txt", "r")
lines = text_file.read().split('\n')

# %%
lines = [w.replace('▁', ' ') for w in lines]
print(lines)
# Out:
# ['<PAD>', '<UNK>', '<BOS>', '<EOS>', ' ', 'a', 'i', 'e', 'o', 'n', 'r', 's', 'а', 't', 'о', 'l', 'u', 'j', 'k', 'd', 'и', 'е', 'н', 'm', 'v', 'p', 'р', 'т', '.', 'с', 'z', ',', 'в', 'c', 'к', 'л', 'g', 'д', 'b', 'м', 'у', '"', 'п', 'і', '1', 'y', 'з', 'г', 'h', 'š', 'w', 'я', 'č', '0', 'ā', 'б', 'ы', '2', '9', 'ч', '=', 'ц', 'ј', 'ž', 'ь', ')', '(', '3', 'х', '8', 'й', '4', '5', '7', 'S', 'f', 'P', '6', 'ш', 'ж', 'ī', 'ł', '-', '>', '<', 'ą', 'A', 'ė', 'ē', 'K', 'I', 'M', 'N', 'B', 'ų', 'ć', 'ў', 'V', 'T', 'ю', 'ę', 'D', '\xa0', 'L', 'R', 'ф', '/', 'ó', 'C', 'G', 'С', 'э', 'П', 'O', '?', 'ū', 'H', '–', ':', 'J', 'В', 'Z', 'ż', 'E', 'К', '—', 'А', 'U', 'F', 'ś', 'М', 'њ', 'ї', 'W', 'Н', 'Б', 'đ', 'Р', 'į', 'щ', 'Д', 'ņ', 'У', 'Г', '«', '»', 'ļ', 'ё', 'Т', 'О', ';', 'Š', '„', 'є', 'X', 'З', 'љ', '%', 'ћ', '“', 'Л', "'", 'ń', 'И', '[', ']', 'Ф', 'Ž', 'Е', 'Х', 'Č', 'ъ', 'ķ', 'ђ', 'ģ', 'І', 'x', '”', 'Ш', 'Ц', 'ќ', 'Ч', '&', 'Y', '_', 'ѓ', 'Ј', 'Я', 'ź', '°', 'é', '{', '}', 'Q', '’', 'Э', '+', '|', 'Ж', 'q', '́', 'Ю', '•', 'á', 'џ', '²', '*', '!', 'Ś', 'ü', 'Є', 'í', 'ö', '−', 'Џ', 'Ā', 'Į', 'α', 'Њ', 'è', '†', '…', 'ä', 'Ż', 'Ķ', 'ο', 'Й', 'Ł', 'ґ', '\xad', 'ν', 'ō', 'ρ', 'ς', '³', 'Đ', 'ι', '·', '№', '$', 'Ē', 'ú', '‘', 'μ', 'Ё', 'π', 'τ', 'ε', '~', 'Ī', 'Ģ', 'λ', 'σ', '×', 'ç', 'Ņ', 'Щ', 'ا', 'γ', 'Ļ', 'Ђ', 'ѕ', 'Ї', 'κ', 'â', 'Ć', 'ë', 'É', 'ñ', 'Љ', 'Ѓ', '#', 'β', 'ø', 'η', 'Ū', 'ã', 'ί', 'ô', 'à', '→', 'õ', 'ل', 'ό', 'ı', 'δ', '\u200b', 'υ', 'Ґ', 'ê', 'ά', 'ر', 'ω', 'ß', 'θ', 'φ', '€', 'ي', 'ѐ', 'ѝ', 'Ö', 'ş', '´', 'م', 'ή', 'ì', 'Á', '‰', 'ò', 'Ќ', 'ő', 'ن', 'έ', 'χ', '±', 'ý', 'ð', 'ب', '`', 'ă', 'å', '\\', 'æ', 'ě', '←', 'و', '′', 'Ћ', 'ğ', 'Δ', 'ː', 'د', 'ə', 'ř', 'ύ', 'ï', 'ζ', 'Å', 'ș', '\u200e', 'º', '½', '│', 'î', 'ة', 'ξ', 'ˈ', 'ӗ', 'ӑ', 'س', '^', 'ع', 'Π', 'ŭ', 'Ѕ', 'י', 'ù', 'Σ', 'Ź', 'µ', 'Î', 'Α', 'ա', 'Κ', '─', 'Ü', 'Μ', 'ʻ', 'Ō', 'ت', 'Ó', '≈', '∙', 'ه', 'ح', '्', 'ו', 'Β', '国', 'ώ', '\u202f', 'ѣ', '░', 'Γ', 'ŗ', 'ה', '£', 'ی', ' p', 'je', ' s', 'na', 'ni', 'ra', ' i', 'st', 'ri', ' k', 'li', 'на', 'ja', 'no', ' t', ' d', ' п', 'ne', 'la', ' v', ' u', ' o', 're', ' с', 'ра', 'ro', 'ie', ' je', 'ma', 'le', 'ko', 'ta', ' z', ' po', 'ka', 'ст', ' 1', 'va', ' na', 'ti', ' в', ' a', 'ни', ' b', 'do', ' m', 'ко', ' g', 'но', 'ка', 'lo', 'ва', ' (', 'to', 'vi', '="', 'та', 'од', 'ki', ' на', 'ci', 'da', ' и', ' д', 'te', 've', 'di', 'vo', 'me', 'ла', 'ро', 'ре', ' з', 'ji', 'ju', ' ko', 'ри', 'то', ' P', 'ar', 'mi', 'ли', ' S', 'не', ' za', 'ga', 'ru', 'doc', ' <', 'go', 'те', 'ле', ' г', 'si', 'jo', ' se', 'ма', ' о', 'sta', ' w', ' ka', 'tu', 'ke', 'de', 'ku', ' 19', 'mo', 'zi', ' по', 'ze', 'ch', ' pa', ' K', 'ме', 'ce', 'po', 'an', ' у', ' б', ' in', ' 2', 'ло', 'ти', 'ки', ' do', ' а', ' A', ' "', 'во', ' ti', ' M', 'se', 'ве', 'či', ' N', ' B', ' iz', 'ль', 'is', 'uri', 'го', 'er', 'nje', ' su', ' ne', ' bi', ' od', 'nie', ' за', ' da', ' sa', ' T', 'ski', 'ви', ' V', 'nu', 'ны', 'је', 'ні', ' ra', 'sti', ' te', 'ја', ' š', ' L', ' D', 'za', 'or', ' pri', 'pa', ' pre', ' e', 'bi', 'да', 'gi', ' ко', 'tle', 'us', ' I', 'ba', 'ми', ' ur', '00', ' f', ' id', 'lu', 'curi', 'd=', 'l="', ' title', ' title="', 'curid=', '?curid=', ' id="', '">', ' url="', ' url="?curid=', '/doc', ' </doc', ' </doc>', ' <doc', ' R', 'ци', 'ži', 'lje', 'га', 'ру', 'sto', ' ir', ' се', 'če', ' С', 'лі', ' pro', 'мо', ' і', ' П', 'al', 'zy', ' me', ' G', ' re', 'ку', 'ча', ' no', 'sko', 'ca', 's,', 'ai', 'au', 'mu', 'кі', 'bo', 'ен', ' J', ' pr', ').', 'wa', ' во', ' ga', ' so', 'ер', ' ve', ' В', ' ma', 'ня', ' ob', 'ста', ' mo', ' H', 'pi', ' O', 's.', 'du', '),', ' ра', ' si', ' Z', 'ры', ' не', 'ny', 'en', ' ка', ' de', 'нс', 'ske', 'по', ' па', ' ta', 'pe', ' до', ' К', ' од', 'cz', 'ля', 'ska', ' је', 'ся', 'sa', 'ту', ' C', 'па', ' le', ' Po', ' go', ' to', ' да', 'ди', 'nt', ' ki', 'lja', ' е', ' la', 'че', 'nih', ' год', ' к', ' М', 'so', ' un', ' E', ' sta', 'gu', 'm.', 'že', 'nja', ' U', ' –', ' h', ' А', ' ar', 'мі', 'ну', 'до ...

# %% [markdown]
# # Encoding texts and making a tokeniser.json

# %%
initial = '{"version":"1.0","truncation":null,"padding":null,"added_tokens":[{"id":50256,"special":true,"content":"<|endoftext|>","single_word":false,"lstrip":false,"rstrip":false,"normalized":true}],"normalizer":null,"pre_tokenizer":{"type":"ByteLevel","add_prefix_space":false,"trim_offsets":true},"post_processor":{"type":"ByteLevel","add_prefix_space":true,"trim_offsets":false},"decoder":{"type":"ByteLevel","add_prefix_space":true,"trim_offsets":true},"model":{"dropout":null,"unk_token":null,"continuing_subword_prefix":"","end_of_word_suffix":"","fuse_unk":false,"vocab":{'
i = 0
for token in lines:
    if '\\' in token:
       token = token.replace('\\', '\\\\')
    if '"' in token:
       token = token.replace('"', '\\"')
    initial = initial + '"' + token + '":' + str(i) + ','
    i = i + 1
initial = initial[:-1]
initial = initial + '},"merges":[]}}'
print(initial)
# Out:
# {"version":"1.0","truncation":null,"padding":null,"added_tokens":[{"id":50256,"special":true,"content":"<|endoftext|>","single_word":false,"lstrip":false,"rstrip":false,"normalized":true}],"normalizer":null,"pre_tokenizer":{"type":"ByteLevel","add_prefix_space":false,"trim_offsets":true},"post_processor":{"type":"ByteLevel","add_prefix_space":true,"trim_offsets":false},"decoder":{"type":"ByteLevel","add_prefix_space":true,"trim_offsets":true},"model":{"dropout":null,"unk_token":null,"continuing_subword_prefix":"","end_of_word_suffix":"","fuse_unk":false,"vocab":{"<PAD>":0,"<UNK>":1,"<BOS>":2,"<EOS>":3," ":4,"a":5,"i":6,"e":7,"o":8,"n":9,"r":10,"s":11,"а":12,"t":13,"о":14,"l":15,"u":16,"j":17,"k":18,"d":19,"и":20,"е":21,"н":22,"m":23,"v":24,"p":25,"р":26,"т":27,".":28,"с":29,"z":30,",":31,"в":32,"c":33,"к":34,"л":35,"g":36,"д":37,"b":38,"м":39,"у":40,"\"":41,"п":42,"і":43,"1":44,"y":45,"з":46,"г":47,"h":48,"š":49,"w":50,"я":51,"č":52,"0":53,"ā":54,"б":55,"ы":56,"2":57,"9":58,"ч":59,"=":60,"ц":61,"ј":62,"ž":63,"ь":64,")":65,"(":66,"3":67,"х":68,"8":69,"й":70,"4":71,"5":72,"7":73,"S":74,"f":75,"P":76,"6":77,"ш":78,"ж":79,"ī":80,"ł":81,"-":82,">":83,"<":84,"ą":85,"A":86,"ė":87,"ē":88,"K":89,"I":90,"M":91,"N":92,"B":93,"ų":94,"ć":95,"ў":96,"V":97,"T":98,"ю":99,"ę":100,"D":101," ":102,"L":103,"R":104,"ф":105,"/":106,"ó":107,"C":108,"G":109,"С":110,"э":111,"П":112,"O":113,"?":114,"ū":115,"H":116,"–":117,":":118,"J":119,"В":120,"Z":121,"ż":122,"E":123,"К":124,"—":125,"А":126,"U":127,"F":128,"ś":129,"М":130,"њ":131,"ї":132,"W":133,"Н":134,"Б":135,"đ":136,"Р":137,"į":138,"щ":139,"Д":140,"ņ":141,"У":142,"Г":143,"«":144,"»":145,"ļ":146,"ё":147,"Т":148,"О":149,";":150,"Š":151,"„":152,"є":153,"X":154,"З":155,"љ":156,"%":157,"ћ":158,"“":159,"Л":160,"'":161,"ń":162,"И":163,"[":164,"]":165,"Ф":166,"Ž":167,"Е":168,"Х":169,"Č":170,"ъ":171,"ķ":172,"ђ":173,"ģ":174,"І":175,"x":176,"”":177,"Ш":178,"Ц":179,"ќ":180,"Ч":181,"&":182,"Y":183,"_":184,"ѓ":185,"Ј":186,"Я":187,"ź":188,"°":189,"é":190,"{":191,"}":192,"Q":193,"’":194,"Э":195,"+":196,"|":197,"Ж":198,"q":199,"́":200,"Ю":201,"•":202,"á":203,"џ":204,"²":205,"*":206,"!":207,"Ś":208,"ü":209,"Є":210,"í":211,"ö":212,"−":213,"Џ":214,"Ā":215,"Į":216,"α":217,"Њ":218,"è":219,"†":220,"…":221,"ä":222,"Ż":223,"Ķ":224,"ο":225,"Й":226,"Ł":227,"ґ":228,"­":229,"ν":230,"ō":231,"ρ":232,"ς":233,"³":234,"Đ":235,"ι":236,"·":237,"№":238,"$":239,"Ē":240,"ú":241,"‘":242,"μ":243,"Ё":244,"π":245,"τ":246,"ε":247,"~":248,"Ī":249,"Ģ":250,"λ":251,"σ":252,"×":253,"ç":254,"Ņ":255,"Щ":256,"ا":257,"γ":258,"Ļ":259,"Ђ":260,"ѕ":261,"Ї":262,"κ":263,"â":264,"Ć":265,"ë":266,"É":267,"ñ":268,"Љ":269,"Ѓ":270,"#":271,"β":272,"ø":273,"η":274,"Ū":275,"ã":276,"ί":277,"ô":278,"à":279,"→":280,"õ":281,"ل":282,"ό":283,"ı":284,"δ":285,"​":286,"υ":287,"Ґ":288,"ê":289,"ά":290,"ر":291,"ω":292,"ß":293,"θ":294,"φ":295,"€":296,"ي":297,"ѐ":298,"ѝ":299,"Ö":300,"ş":301,"´":302,"م":303,"ή":304,"ì":305,"Á":306,"‰":307,"ò":308,"Ќ":309,"ő":310,"ن":311,"έ":312,"χ":313,"±":314,"ý":315,"ð":316,"ب":317,"`":318,"ă":319,"å":320,"\\":321,"æ":322,"ě":323,"←":324,"و":325,"′":326,"Ћ":327,"ğ":328,"Δ":329,"ː":330,"د":331,"ə":332,"ř":333,"ύ":334,"ï":335,"ζ":336,"Å":337,"ș":338,"‎":339,"º":340,"½":341,"│":342,"î":343,"ة":344,"ξ":345,"ˈ":346,"ӗ":347,"ӑ":348,"س":349,"^":350,"ع":351,"Π":352,"ŭ":353,"Ѕ":354,"י":355,"ù":356,"Σ":357,"Ź":358,"µ":359,"Î":360,"Α":361,"ա":362,"Κ":363,"─":364,"Ü":365,"Μ":366,"ʻ":367,"Ō":368,"ت":369,"Ó":370,"≈":371,"∙":372,"ه":373,"ح":374,"्":375,"ו":376,"Β":377,"国":378,"ώ":379," ":380,"ѣ":381,"░":382,"Γ":383,"ŗ":384,"ה":385,"£":386,"ی":387," p":388,"je":389," s":390,"na":391,"ni":392,"ra":393," i":394,"st":395,"ri":396," k":397,"li":398,"на":399,"ja":400,"no":401," t":402," d":403," п":404,"ne":405,"la":406," v":407," u":408," o":409,"re":410," с":411,"ра":412,"ro":413,"ie":414," je":415,"ma":416,"le":417,"ko":418,"ta":419," z":420," po":421,"ka":422,"ст":423," 1":424,"va":425," na":426,"ti":427," в":428," a":429,"ни":430," b":431,"do":432," m":433,"к ...

# %%
with open("aitextgen.tokeniser.json", "w") as text_file:
    text_file.write(initial)

# %%
# !yttm encode --model /content/model --n_threads 8 --dropout_prob 0.25 --output_type id < /content/final_untokenised.txt > final.txt
# Out:
# n_threads: 8
# bytes processed: 2076211180

# %% [markdown]
# # Saving as npy array

# %% [markdown]
# There may be a more efficient way of doing this. I tried using linecache to read specific lines and then multithreaded it but then np.save broke, I'm not sure why.

# %%
# !cat /content/final.txt /content/translations_tokenised_new.txt FINAL_ALL.txt

# %%
from pathlib import Path
import numpy as np
import os
import re
file = open("dataset_tokenized.txt")
i = 0
allLines = []
while 1:
    allLines = []
    i = i + 50000000
    string_data = file.read(50000000)
    if not string_data:
        break
    list_data = re.split(' |\n',string_data)
    list_data = list(filter(None, list_data))
    arr = np.array(list_data, dtype=np.uint16)
    f_handle = open('data.npy', 'ab')
    np.save(f_handle, arr)
    f_handle.close()
    print('Line ' + str(i) + ' done!')

# %%
# !gzip data.npy

# %%
# !cp data.npy.gz /content/drive/MyDrive/
